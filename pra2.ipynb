# %% [markdown]
# <a href="https://colab.research.google.com/github/JamdhadeVikrant/Carbon-Footprint-Tracking/blob/main/pra2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/data.csv")

# %%
df
# Out:
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 0    1        64.0    Male  7458612987               61           47.0
# 1    2        11.0    Male  7458612988               95           46.0
# 2    3        41.0    Male  7458612989               78           99.0
# 3    4        86.0    Male  7458612990               71           97.0
# 4    5         1.0    Male  7458612991               25           62.0
# ..  ..         ...     ...         ...              ...            ...
# 85  86        69.0    Male  7458613072               74           64.0
# 86  87        13.0    Male  7458613073               97           80.0
# 87  88        10.0  Female  7458613074               25           44.0
# 88  89        65.0  Female  7458613075               78           76.0
# 89  90        35.0    Male  7458613076               48           21.0
#
#     writing score  club join year  placement offer count
# 0            23.0            2023                    1.0
# 1            59.0            2011                    1.0
# 2            45.0            2024                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# ..            ...             ...                    ...
# 85           15.0            2019                    1.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0
# 88           24.0            2022                    1.0
# 89           65.0            2012                    1.0
#
# [90 rows x 9 columns]

# %%
df.isnull()
# Out:
#        Id  math score  gender  Phone no  Placement Score  reading score  \
# 0   False       False   False     False            False          False
# 1   False       False   False     False            False          False
# 2   False       False   False     False            False          False
# 3   False       False   False     False            False          False
# 4   False       False   False     False            False          False
# ..    ...         ...     ...       ...              ...            ...
# 85  False       False   False     False            False          False
# 86  False       False   False     False            False          False
# 87  False       False   False     False            False          False
# 88  False       False   False     False            False          False
# 89  False       False   False     False            False          False
#
#     writing score  club join year  placement offer count
# 0           False           False                  False
# 1           False           False                  False
# 2           False           False                  False
# 3           False           False                  False
# 4           False           False                  False
# ..            ...             ...                    ...
# 85          False           False                  False
# 86          False           False                  False
# 87          False           False                  False
# 88          False           False                  False
# 89          False           False                  False
#
# [90 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Id                       0
# math score               1
# gender                   0
# Phone no                 0
# Placement Score          0
# reading score            3
# writing score            2
# club join year           0
# placement offer count    1
# dtype: int64

# %%
df.notnull()
# Out:
#       Id  math score  gender  Phone no  Placement Score  reading score  \
# 0   True        True    True      True             True           True
# 1   True        True    True      True             True           True
# 2   True        True    True      True             True           True
# 3   True        True    True      True             True           True
# 4   True        True    True      True             True           True
# ..   ...         ...     ...       ...              ...            ...
# 85  True        True    True      True             True           True
# 86  True        True    True      True             True           True
# 87  True        True    True      True             True           True
# 88  True        True    True      True             True           True
# 89  True        True    True      True             True           True
#
#     writing score  club join year  placement offer count
# 0            True            True                   True
# 1            True            True                   True
# 2            True            True                   True
# 3            True            True                   True
# 4            True            True                   True
# ..            ...             ...                    ...
# 85           True            True                   True
# 86           True            True                   True
# 87           True            True                   True
# 88           True            True                   True
# 89           True            True                   True
#
# [90 rows x 9 columns]

# %%
df.fillna(0)
# Out:
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 0    1        64.0    Male  7458612987               61           47.0
# 1    2        11.0    Male  7458612988               95           46.0
# 2    3        41.0    Male  7458612989               78           99.0
# 3    4        86.0    Male  7458612990               71           97.0
# 4    5         1.0    Male  7458612991               25           62.0
# ..  ..         ...     ...         ...              ...            ...
# 85  86        69.0    Male  7458613072               74           64.0
# 86  87        13.0    Male  7458613073               97           80.0
# 87  88        10.0  Female  7458613074               25           44.0
# 88  89        65.0  Female  7458613075               78           76.0
# 89  90        35.0    Male  7458613076               48           21.0
#
#     writing score  club join year  placement offer count
# 0            23.0            2023                    1.0
# 1            59.0            2011                    1.0
# 2            45.0            2024                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# ..            ...             ...                    ...
# 85           15.0            2019                    1.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0
# 88           24.0            2022                    1.0
# 89           65.0            2012                    1.0
#
# [90 rows x 9 columns]

# %%
df.isnull()
# Out:
#        Id  math score  gender  Phone no  Placement Score  reading score  \
# 0   False       False   False     False            False          False
# 1   False       False   False     False            False          False
# 2   False       False   False     False            False          False
# 3   False       False   False     False            False          False
# 4   False       False   False     False            False          False
# ..    ...         ...     ...       ...              ...            ...
# 85  False       False   False     False            False          False
# 86  False       False   False     False            False          False
# 87  False       False   False     False            False          False
# 88  False       False   False     False            False          False
# 89  False       False   False     False            False          False
#
#     writing score  club join year  placement offer count
# 0           False           False                  False
# 1           False           False                  False
# 2           False           False                  False
# 3           False           False                  False
# 4           False           False                  False
# ..            ...             ...                    ...
# 85          False           False                  False
# 86          False           False                  False
# 87          False           False                  False
# 88          False           False                  False
# 89          False           False                  False
#
# [90 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Id                       0
# math score               0
# gender                   0
# Phone no                 0
# Placement Score          0
# reading score            0
# writing score            2
# club join year           0
# placement offer count    1
# dtype: int64

# %%
series = pd.isnull(df["math score"])
df[series]
# Out:
#     Id  math score gender    Phone no  Placement Score  reading score  \
# 41  42         NaN   Male  7458613028               98           43.0
#
#     writing score  club join year  placement offer count
# 41           63.0            2010                    1.0

# %%
series1 = pd.notnull(df["math score"])
df[series1]
# Out:
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 0    1        64.0    Male  7458612987               61           47.0
# 1    2        11.0    Male  7458612988               95           46.0
# 2    3        41.0    Male  7458612989               78           99.0
# 3    4        86.0    Male  7458612990               71           97.0
# 4    5         1.0    Male  7458612991               25           62.0
# ..  ..         ...     ...         ...              ...            ...
# 85  86        69.0    Male  7458613072               74           64.0
# 86  87        13.0    Male  7458613073               97           80.0
# 87  88        10.0  Female  7458613074               25           44.0
# 88  89        65.0  Female  7458613075               78           76.0
# 89  90        35.0    Male  7458613076               48           21.0
#
#     writing score  club join year  placement offer count
# 0            23.0            2023                    1.0
# 1            59.0            2011                    1.0
# 2            45.0            2024                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# ..            ...             ...                    ...
# 85           15.0            2019                    1.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0
# 88           24.0            2022                    1.0
# 89           65.0            2012                    1.0
#
# [89 rows x 9 columns]

# %%
v=df
v.fillna(0)
# Out:
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 0    1        64.0    Male  7458612987               61           47.0
# 1    2        11.0    Male  7458612988               95           46.0
# 2    3        41.0    Male  7458612989               78           99.0
# 3    4        86.0    Male  7458612990               71           97.0
# 4    5         1.0    Male  7458612991               25           62.0
# ..  ..         ...     ...         ...              ...            ...
# 85  86        69.0    Male  7458613072               74           64.0
# 86  87        13.0    Male  7458613073               97           80.0
# 87  88        10.0  Female  7458613074               25           44.0
# 88  89        65.0  Female  7458613075               78           76.0
# 89  90        35.0    Male  7458613076               48           21.0
#
#     writing score  club join year  placement offer count
# 0            23.0            2023                    1.0
# 1            59.0            2011                    1.0
# 2            45.0            2024                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# ..            ...             ...                    ...
# 85           15.0            2019                    1.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0
# 88           24.0            2022                    1.0
# 89           65.0            2012                    1.0
#
# [90 rows x 9 columns]

# %%
m_v=df['math score'].mean()
df['math score'].fillna(value=m_v, inplace=True)
df
# Out:
# /tmp/ipython-input-2022259280.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['math score'].fillna(value=m_v, inplace=True)
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 0    1        64.0    Male  7458612987               61           47.0
# 1    2        11.0    Male  7458612988               95           46.0
# 2    3        41.0    Male  7458612989               78           99.0
# 3    4        86.0    Male  7458612990               71           97.0
# 4    5         1.0    Male  7458612991               25           62.0
# ..  ..         ...     ...         ...              ...            ...
# 85  86        69.0    Male  7458613072               74           64.0
# 86  87        13.0    Male  7458613073               97           80.0
# 87  88        10.0  Female  7458613074               25           44.0
# 88  89        65.0  Female  7458613075               78           76.0
# 89  90        35.0    Male  7458613076               48           21.0
#
#     writing score  club join year  placement offer count
# 0            23.0            2023                    1.0
# 1            59.0            2011                    1.0
# 2            45.0            2024                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# ..            ...             ...                    ...
# 85           15.0            2019                    1.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0
# 88           24.0            2022                    1.0
# 89           65.0            2012                    1.0
#
# [90 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Id                       0
# math score               0
# gender                   0
# Phone no                 0
# Placement Score          0
# reading score            3
# writing score            2
# club join year           0
# placement offer count    1
# dtype: int64

# %%
m_v=df['reading score'].mean()
df['reading score'].fillna(value=m_v, inplace=True)
df
# Out:
# /tmp/ipython-input-800877498.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['reading score'].fillna(value=m_v, inplace=True)
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 0    1        64.0    Male  7458612987               61           47.0
# 1    2        11.0    Male  7458612988               95           46.0
# 2    3        41.0    Male  7458612989               78           99.0
# 3    4        86.0    Male  7458612990               71           97.0
# 4    5         1.0    Male  7458612991               25           62.0
# ..  ..         ...     ...         ...              ...            ...
# 85  86        69.0    Male  7458613072               74           64.0
# 86  87        13.0    Male  7458613073               97           80.0
# 87  88        10.0  Female  7458613074               25           44.0
# 88  89        65.0  Female  7458613075               78           76.0
# 89  90        35.0    Male  7458613076               48           21.0
#
#     writing score  club join year  placement offer count
# 0            23.0            2023                    1.0
# 1            59.0            2011                    1.0
# 2            45.0            2024                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# ..            ...             ...                    ...
# 85           15.0            2019                    1.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0
# 88           24.0            2022                    1.0
# 89           65.0            2012                    1.0
#
# [90 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Id                       0
# math score               0
# gender                   0
# Phone no                 0
# Placement Score          0
# reading score            0
# writing score            2
# club join year           0
# placement offer count    1
# dtype: int64

# %%
v.replace(to_replace = np.nan, value = -99)
# Out:
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 0    1        64.0    Male  7458612987               61           47.0
# 1    2        11.0    Male  7458612988               95           46.0
# 2    3        41.0    Male  7458612989               78           99.0
# 3    4        86.0    Male  7458612990               71           97.0
# 4    5         1.0    Male  7458612991               25           62.0
# ..  ..         ...     ...         ...              ...            ...
# 85  86        69.0    Male  7458613072               74           64.0
# 86  87        13.0    Male  7458613073               97           80.0
# 87  88        10.0  Female  7458613074               25           44.0
# 88  89        65.0  Female  7458613075               78           76.0
# 89  90        35.0    Male  7458613076               48           21.0
#
#     writing score  club join year  placement offer count
# 0            23.0            2023                    1.0
# 1            59.0            2011                    1.0
# 2            45.0            2024                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# ..            ...             ...                    ...
# 85           15.0            2019                    1.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0
# 88           24.0            2022                    1.0
# 89           65.0            2012                    1.0
#
# [90 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Id                       0
# math score               0
# gender                   0
# Phone no                 0
# Placement Score          0
# reading score            0
# writing score            2
# club join year           0
# placement offer count    1
# dtype: int64

# %%
series1 = pd.notnull(df["math score"])
df[series1]
# Out:
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 0    1        64.0    Male  7458612987               61           47.0
# 1    2        11.0    Male  7458612988               95           46.0
# 2    3        41.0    Male  7458612989               78           99.0
# 3    4        86.0    Male  7458612990               71           97.0
# 4    5         1.0    Male  7458612991               25           62.0
# ..  ..         ...     ...         ...              ...            ...
# 85  86        69.0    Male  7458613072               74           64.0
# 86  87        13.0    Male  7458613073               97           80.0
# 87  88        10.0  Female  7458613074               25           44.0
# 88  89        65.0  Female  7458613075               78           76.0
# 89  90        35.0    Male  7458613076               48           21.0
#
#     writing score  club join year  placement offer count
# 0            23.0            2023                    1.0
# 1            59.0            2011                    1.0
# 2            45.0            2024                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# ..            ...             ...                    ...
# 85           15.0            2019                    1.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0
# 88           24.0            2022                    1.0
# 89           65.0            2012                    1.0
#
# [90 rows x 9 columns]

# %%
print(np.where(df['reading score']<25))
print(np.where(df['writing score']<30))
# Out:
# (array([ 8,  9, 12, 34, 38, 42, 43, 44, 46, 52, 61, 67, 78, 79, 82, 89]),)
# (array([ 0,  4,  6, 10, 14, 19, 22, 23, 28, 30, 32, 33, 38, 46, 52, 57, 62,
#        70, 73, 75, 76, 77, 79, 81, 84, 85, 88]),)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['gender'] = le.fit_transform(df['gender'])
newdf=df

# %%
missing_values = ["Na", "na"]

# %%
na_values =missing_values
df
# Out:
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 0    1        64.0       1  7458612987               61           47.0
# 1    2        11.0       1  7458612988               95           46.0
# 2    3        41.0       1  7458612989               78           99.0
# 3    4        86.0       1  7458612990               71           97.0
# 4    5         1.0       1  7458612991               25           62.0
# ..  ..         ...     ...         ...              ...            ...
# 85  86        69.0       1  7458613072               74           64.0
# 86  87        13.0       1  7458613073               97           80.0
# 87  88        10.0       0  7458613074               25           44.0
# 88  89        65.0       0  7458613075               78           76.0
# 89  90        35.0       1  7458613076               48           21.0
#
#     writing score  club join year  placement offer count
# 0            23.0            2023                    1.0
# 1            59.0            2011                    1.0
# 2            45.0            2024                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# ..            ...             ...                    ...
# 85           15.0            2019                    1.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0
# 88           24.0            2022                    1.0
# 89           65.0            2012                    1.0
#
# [90 rows x 9 columns]

# %%
ndf=df
ndf.fillna(0)
# Out:
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 0    1        64.0       1  7458612987               61           47.0
# 1    2        11.0       1  7458612988               95           46.0
# 2    3        41.0       1  7458612989               78           99.0
# 3    4        86.0       1  7458612990               71           97.0
# 4    5         1.0       1  7458612991               25           62.0
# ..  ..         ...     ...         ...              ...            ...
# 85  86        69.0       1  7458613072               74           64.0
# 86  87        13.0       1  7458613073               97           80.0
# 87  88        10.0       0  7458613074               25           44.0
# 88  89        65.0       0  7458613075               78           76.0
# 89  90        35.0       1  7458613076               48           21.0
#
#     writing score  club join year  placement offer count
# 0            23.0            2023                    1.0
# 1            59.0            2011                    1.0
# 2            45.0            2024                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# ..            ...             ...                    ...
# 85           15.0            2019                    1.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0
# 88           24.0            2022                    1.0
# 89           65.0            2012                    1.0
#
# [90 rows x 9 columns]

# %%
import matplotlib.pyplot as plt

# %%
m_v=df['math score'].mean()
df['math score'].fillna(value=m_v, inplace=True)
df
# Out:
# /tmp/ipython-input-2022259280.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['math score'].fillna(value=m_v, inplace=True)
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 0    1        64.0       1  7458612987               61           47.0
# 1    2        11.0       1  7458612988               95           46.0
# 2    3        41.0       1  7458612989               78           99.0
# 3    4        86.0       1  7458612990               71           97.0
# 4    5         1.0       1  7458612991               25           62.0
# ..  ..         ...     ...         ...              ...            ...
# 85  86        69.0       1  7458613072               74           64.0
# 86  87        13.0       1  7458613073               97           80.0
# 87  88        10.0       0  7458613074               25           44.0
# 88  89        65.0       0  7458613075               78           76.0
# 89  90        35.0       1  7458613076               48           21.0
#
#     writing score  club join year  placement offer count
# 0            23.0            2023                    1.0
# 1            59.0            2011                    1.0
# 2            45.0            2024                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# ..            ...             ...                    ...
# 85           15.0            2019                    1.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0
# 88           24.0            2022                    1.0
# 89           65.0            2012                    1.0
#
# [90 rows x 9 columns]

# %%
ndf.replace(to_replace = np.nan, value = -99)
# Out:
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 0    1        64.0       1  7458612987               61           47.0
# 1    2        11.0       1  7458612988               95           46.0
# 2    3        41.0       1  7458612989               78           99.0
# 3    4        86.0       1  7458612990               71           97.0
# 4    5         1.0       1  7458612991               25           62.0
# ..  ..         ...     ...         ...              ...            ...
# 85  86        69.0       1  7458613072               74           64.0
# 86  87        13.0       1  7458613073               97           80.0
# 87  88        10.0       0  7458613074               25           44.0
# 88  89        65.0       0  7458613075               78           76.0
# 89  90        35.0       1  7458613076               48           21.0
#
#     writing score  club join year  placement offer count
# 0            23.0            2023                    1.0
# 1            59.0            2011                    1.0
# 2            45.0            2024                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# ..            ...             ...                    ...
# 85           15.0            2019                    1.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0
# 88           24.0            2022                    1.0
# 89           65.0            2012                    1.0
#
# [90 rows x 9 columns]

# %%
ndf.dropna()
# Out:
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 0    1        64.0       1  7458612987               61           47.0
# 1    2        11.0       1  7458612988               95           46.0
# 2    3        41.0       1  7458612989               78           99.0
# 3    4        86.0       1  7458612990               71           97.0
# 4    5         1.0       1  7458612991               25           62.0
# ..  ..         ...     ...         ...              ...            ...
# 85  86        69.0       1  7458613072               74           64.0
# 86  87        13.0       1  7458613073               97           80.0
# 87  88        10.0       0  7458613074               25           44.0
# 88  89        65.0       0  7458613075               78           76.0
# 89  90        35.0       1  7458613076               48           21.0
#
#     writing score  club join year  placement offer count
# 0            23.0            2023                    1.0
# 1            59.0            2011                    1.0
# 2            45.0            2024                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# ..            ...             ...                    ...
# 85           15.0            2019                    1.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0
# 88           24.0            2022                    1.0
# 89           65.0            2012                    1.0
#
# [87 rows x 9 columns]

# %%
ndf.dropna(how = 'all')
# Out:
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 0    1        64.0       1  7458612987               61           47.0
# 1    2        11.0       1  7458612988               95           46.0
# 2    3        41.0       1  7458612989               78           99.0
# 3    4        86.0       1  7458612990               71           97.0
# 4    5         1.0       1  7458612991               25           62.0
# ..  ..         ...     ...         ...              ...            ...
# 85  86        69.0       1  7458613072               74           64.0
# 86  87        13.0       1  7458613073               97           80.0
# 87  88        10.0       0  7458613074               25           44.0
# 88  89        65.0       0  7458613075               78           76.0
# 89  90        35.0       1  7458613076               48           21.0
#
#     writing score  club join year  placement offer count
# 0            23.0            2023                    1.0
# 1            59.0            2011                    1.0
# 2            45.0            2024                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# ..            ...             ...                    ...
# 85           15.0            2019                    1.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0
# 88           24.0            2022                    1.0
# 89           65.0            2012                    1.0
#
# [90 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Id                       0
# math score               0
# gender                   0
# Phone no                 0
# Placement Score          0
# reading score            0
# writing score            2
# club join year           0
# placement offer count    1
# dtype: int64

# %%
m_v=df['writing score'].mean()
df['writing score'].fillna(value=m_v, inplace=True)
df
# Out:
# /tmp/ipython-input-4193908214.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['writing score'].fillna(value=m_v, inplace=True)
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 0    1        64.0       1  7458612987               61           47.0
# 1    2        11.0       1  7458612988               95           46.0
# 2    3        41.0       1  7458612989               78           99.0
# 3    4        86.0       1  7458612990               71           97.0
# 4    5         1.0       1  7458612991               25           62.0
# ..  ..         ...     ...         ...              ...            ...
# 85  86        69.0       1  7458613072               74           64.0
# 86  87        13.0       1  7458613073               97           80.0
# 87  88        10.0       0  7458613074               25           44.0
# 88  89        65.0       0  7458613075               78           76.0
# 89  90        35.0       1  7458613076               48           21.0
#
#     writing score  club join year  placement offer count
# 0            23.0            2023                    1.0
# 1            59.0            2011                    1.0
# 2            45.0            2024                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# ..            ...             ...                    ...
# 85           15.0            2019                    1.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0
# 88           24.0            2022                    1.0
# 89           65.0            2012                    1.0
#
# [90 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Id                       0
# math score               0
# gender                   0
# Phone no                 0
# Placement Score          0
# reading score            0
# writing score            0
# club join year           0
# placement offer count    1
# dtype: int64

# %%
m_v=df['placement offer count'].mean()
df['placement offer count'].fillna(value=m_v, inplace=True)
df
# Out:
# /tmp/ipython-input-35205780.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['placement offer count'].fillna(value=m_v, inplace=True)
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 0    1        64.0       1  7458612987               61           47.0
# 1    2        11.0       1  7458612988               95           46.0
# 2    3        41.0       1  7458612989               78           99.0
# 3    4        86.0       1  7458612990               71           97.0
# 4    5         1.0       1  7458612991               25           62.0
# ..  ..         ...     ...         ...              ...            ...
# 85  86        69.0       1  7458613072               74           64.0
# 86  87        13.0       1  7458613073               97           80.0
# 87  88        10.0       0  7458613074               25           44.0
# 88  89        65.0       0  7458613075               78           76.0
# 89  90        35.0       1  7458613076               48           21.0
#
#     writing score  club join year  placement offer count
# 0            23.0            2023                    1.0
# 1            59.0            2011                    1.0
# 2            45.0            2024                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# ..            ...             ...                    ...
# 85           15.0            2019                    1.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0
# 88           24.0            2022                    1.0
# 89           65.0            2012                    1.0
#
# [90 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Id                       0
# math score               0
# gender                   0
# Phone no                 0
# Placement Score          0
# reading score            0
# writing score            0
# club join year           0
# placement offer count    0
# dtype: int64

# %%
ndf.isnull().sum()
# Out:
# Id                       0
# math score               0
# gender                   0
# Phone no                 0
# Placement Score          0
# reading score            0
# writing score            0
# club join year           0
# placement offer count    0
# dtype: int64

# %%
ndf.dropna(axis = 1)
# Out:
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 0    1        64.0       1  7458612987               61           47.0
# 1    2        11.0       1  7458612988               95           46.0
# 2    3        41.0       1  7458612989               78           99.0
# 3    4        86.0       1  7458612990               71           97.0
# 4    5         1.0       1  7458612991               25           62.0
# ..  ..         ...     ...         ...              ...            ...
# 85  86        69.0       1  7458613072               74           64.0
# 86  87        13.0       1  7458613073               97           80.0
# 87  88        10.0       0  7458613074               25           44.0
# 88  89        65.0       0  7458613075               78           76.0
# 89  90        35.0       1  7458613076               48           21.0
#
#     writing score  club join year  placement offer count
# 0            23.0            2023                    1.0
# 1            59.0            2011                    1.0
# 2            45.0            2024                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# ..            ...             ...                    ...
# 85           15.0            2019                    1.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0
# 88           24.0            2022                    1.0
# 89           65.0            2012                    1.0
#
# [90 rows x 9 columns]

# %%
new_data = ndf.dropna(axis = 0, how ='any')

# %%
new_data
# Out:
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 0    1        64.0       1  7458612987               61           47.0
# 1    2        11.0       1  7458612988               95           46.0
# 2    3        41.0       1  7458612989               78           99.0
# 3    4        86.0       1  7458612990               71           97.0
# 4    5         1.0       1  7458612991               25           62.0
# ..  ..         ...     ...         ...              ...            ...
# 85  86        69.0       1  7458613072               74           64.0
# 86  87        13.0       1  7458613073               97           80.0
# 87  88        10.0       0  7458613074               25           44.0
# 88  89        65.0       0  7458613075               78           76.0
# 89  90        35.0       1  7458613076               48           21.0
#
#     writing score  club join year  placement offer count
# 0            23.0            2023                    1.0
# 1            59.0            2011                    1.0
# 2            45.0            2024                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# ..            ...             ...                    ...
# 85           15.0            2019                    1.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0
# 88           24.0            2022                    1.0
# 89           65.0            2012                    1.0
#
# [90 rows x 9 columns]

# %%
col = ['math score', 'reading score' , 'writing score','Placement Score']
df.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(df['math score']>90))
# Out:
# (array([10, 14, 24, 27, 33, 38, 74, 78, 83]),)

# %%
print(np.where(df['reading score']<25))
print(np.where(df['writing score']<30))
# Out:
# (array([ 8,  9, 12, 34, 38, 42, 43, 44, 46, 52, 61, 67, 78, 79, 82, 89]),)
# (array([ 0,  4,  6, 10, 14, 19, 22, 23, 28, 30, 32, 33, 38, 46, 52, 57, 62,
#        70, 73, 75, 76, 77, 79, 81, 84, 85, 88]),)

# %%
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['Placement Score'], df['placement offer count'])
plt.show()

# %%
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['Placement Score'], df['placement offer count'])
plt.show()
ax.set_xlabel('(Proportion non-retail businessacres)/(town)')
ax.set_ylabel('(Full-value property-tax rate)/($10,000)')
# Out:
# Text(4.444444444444452, 0.5, '(Full-value property-tax rate)/($10,000)')

# %%
print(np.where((df['Placement Score']<50) & (df['placement offer count']>1)))
print(np.where((df['Placement Score']>85) & (df['placement offer count']<3)))
# Out:
# (array([11, 13, 14, 24, 27, 31, 33, 38, 47, 55, 62, 64, 66, 68, 73, 78]),)
# (array([ 1, 10, 17, 41, 45, 65, 76, 79, 83, 86]),)

# %%
from scipy import stats
z = np.abs(stats.zscore(df['math score']))
print(z)
# Out:
# [4.18421676e-01 1.27865059e+00 3.18043647e-01 1.12286677e+00
#  1.59885291e+00 7.70644223e-01 5.78522834e-01 1.94280056e-01
#  9.94785843e-01 2.98615642e-02 1.37902862e+00 1.18690723e+00
#  1.63087314e+00 8.98725149e-01 1.57115001e+00 1.15056967e+00
#  6.42563297e-01 1.53481244e+00 2.86023416e-01 1.05450897e+00
#  6.70266194e-01 1.59885291e+00 2.58320519e-01 6.10543065e-01
#  1.41104885e+00 4.82462139e-01 1.94280056e-01 1.34700839e+00
#  1.31067082e+00 7.70644223e-01 9.26428045e-01 1.12286677e+00
#  4.78144805e-01 1.31498816e+00 4.82462139e-01 1.63087314e+00
#  1.02680607e+00 7.98347120e-01 1.31498816e+00 6.10543065e-01
#  8.30367351e-01 2.27517429e-16 2.58320519e-01 2.21982953e-01
#  1.37471129e+00 7.06603760e-01 1.27865059e+00 9.62765611e-01
#  6.74583528e-01 1.59885291e+00 6.18817957e-02 1.37471129e+00
#  4.46124573e-01 8.02664454e-01 3.18043647e-01 8.02664454e-01
#  1.47077198e+00 8.62387582e-01 2.58320519e-01 4.78144805e-01
#  8.66704917e-01 5.14482371e-01 1.25094769e+00 1.59885291e+00
#  1.21892746e+00 4.46124573e-01 1.12286677e+00 1.25922259e-01
#  1.21892746e+00 8.30367351e-01 1.27865059e+00 7.38623991e-01
#  1.43875175e+00 1.21892746e+00 1.28296793e+00 2.54003184e-01
#  7.98347120e-01 1.27865059e+00 1.28296793e+00 7.38623991e-01
#  7.98347120e-01 9.82193617e-02 1.43875175e+00 1.57115001e+00
#  6.10543065e-01 5.78522834e-01 1.21461013e+00 1.31067082e+00
#  4.50441908e-01 5.10165036e-01]

# %%
threshold = 1

# %%
sample_outliers = np.where(z <threshold)
sample_outliers
# Out:
# (array([ 0,  2,  5,  6,  7,  8,  9, 13, 16, 18, 20, 22, 23, 25, 26, 29, 30,
#         32, 34, 37, 39, 40, 41, 42, 43, 45, 47, 48, 50, 52, 53, 54, 55, 57,
#         58, 59, 60, 61, 65, 67, 69, 71, 75, 76, 79, 80, 81, 84, 85, 88, 89]),)

# %%
col = ['reading score']
df.boxplot(col)
# Out:
# <Axes: >

# %%
sorted_rscore= sorted(df['reading score'])

# %%
sorted_rscore
# Out:
# [0.0,
#  2.0,
#  5.0,
#  5.0,
#  5.0,
#  9.0,
#  9.0,
#  12.0,
#  15.0,
#  20.0,
#  21.0,
#  21.0,
#  22.0,
#  23.0,
#  23.0,
#  24.0,
#  25.0,
#  25.0,
#  33.0,
#  33.0,
#  34.0,
#  36.0,
#  36.0,
#  37.0,
#  39.0,
#  39.0,
#  39.0,
#  39.0,
#  41.0,
#  43.0,
#  44.0,
#  45.0,
#  46.0,
#  47.0,
#  47.0,
#  48.0,
#  49.0,
#  49.0,
#  51.0,
#  51.0,
#  52.0,
#  52.0,
#  54.0,
#  54.0,
#  55.62068965517241,
#  55.62068965517241,
#  55.62068965517241,
#  58.0,
#  59.0,
#  60.0,
#  60.0,
#  61.0,
#  61.0,
#  62.0,
#  62.0,
#  62.0,
#  64.0,
#  66.0,
#  69.0,
#  70.0,
#  72.0,
#  73.0,
#  74.0,
#  76.0,
#  76.0,
#  77.0,
#  77.0,
#  78.0,
#  79.0,
#  79.0,
#  80.0,
#  82.0,
#  87.0,
#  87.0,
#  87.0,
#  89.0,
#  89.0,
#  91.0,
#  94.0,
#  96.0,
#  96.0,
#  96.0,
#  96.0,
#  97.0,
#  98.0,
#  98.0,
#  99.0,
#  99.0,
#  99.0,
#  100.0]

# %%
q1 = np.percentile(sorted_rscore, 25)
q3 = np.percentile(sorted_rscore, 75)
print(q1,q3)
# Out:
# 36.25 77.75

# %%
IQR = q3-q1

# %%
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)
print(lwr_bound, upr_bound)
# Out:
# -26.0 140.0

# %%
r_outliers = []
for i in sorted_rscore:
 if (i<lwr_bound or i>upr_bound):r_outliers.append(i)
print(r_outliers)
# Out:
# []

# %%
new_df=df
for i in sample_outliers:
 new_df.drop(i,inplace=True)
new_df
# Out:
#     Id  math score  gender    Phone no  Placement Score  reading score  \
# 1    2        11.0       1  7458612988               95       46.00000
# 3    4        86.0       1  7458612990               71       97.00000
# 4    5         1.0       1  7458612991               25       62.00000
# 10  11        94.0       0  7458612997               89       60.00000
# 11  12        88.0       1  7458612998               16       73.00000
# 12  13         0.0       0  7458612999               16        9.00000
# 14  15       100.0       1  7458613001               28       58.00000
# 15  16        15.0       1  7458613002                4       51.00000
# 17  18         3.0       1  7458613004               87       76.00000
# 19  20        18.0       0  7458613006               45       89.00000
# 21  22         1.0       0  7458613008               15       39.00000
# 24  25        95.0       1  7458613011               46       87.00000
# 27  28        93.0       1  7458613014                1       36.00000
# 28  29        10.0       0  7458613015               44       61.00000
# 31  32        86.0       1  7458613018                9       94.00000
# 33  34        92.0       0  7458613020               23       37.00000
# 35  36         0.0       0  7458613022               60       25.00000
# 36  37        83.0       0  7458613023               50       74.00000
# 38  39        92.0       0  7458613025               17       15.00000
# 44  45         8.0       0  7458613031               79       21.00000
# 46  47        11.0       0  7458613033               36        5.00000
# 49  50         1.0       0  7458613036                9       96.00000
# 51  52         8.0       1  7458613038               31       49.00000
# 56  57         5.0       1  7458613043               32       33.00000
# 62  63        90.0       0  7458613049                1       41.00000
# 63  64         1.0       1  7458613050               13       98.00000
# 64  65        89.0       1  7458613051               19       47.00000
# 66  67        86.0       0  7458613053                6       77.00000
# 68  69        89.0       1  7458613055                0       62.00000
# 70  71        11.0       0  7458613057               24      100.00000
# 72  73         6.0       1  7458613059               66       36.00000
# 73  74        89.0       0  7458613060               29       82.00000
# 74  75        91.0       0  7458613061               82       99.00000
# 77  78        11.0       1  7458613064               27       52.00000
# 78  79        91.0       1  7458613065               27        5.00000
# 82  83         6.0       0  7458613069               82       12.00000
# 83  84       100.0       0  7458613070               87       55.62069
# 86  87        13.0       1  7458613073               97       80.00000
# 87  88        10.0       0  7458613074               25       44.00000
#
#     writing score  club join year  placement offer count
# 1            59.0            2011                    1.0
# 3            94.0            2011                    2.0
# 4            11.0            2015                    1.0
# 10            4.0            2022                    2.0
# 11           88.0            2016                    2.0
# 12           80.0            2019                    1.0
# 14           29.0            2019                    2.0
# 15           50.0            2014                    1.0
# 17           50.0            2025                    1.0
# 19           26.0            2011                    1.0
# 21           92.0            2024                    1.0
# 24           86.0            2023                    2.0
# 27           31.0            2017                    2.0
# 28            5.0            2012                    1.0
# 31           66.0            2024                    2.0
# 33            2.0            2015                    2.0
# 35           94.0            2023                    1.0
# 36           93.0            2021                    3.0
# 38           18.0            2013                    2.0
# 44           45.0            2016                    1.0
# 46            7.0            2024                    1.0
# 49           42.0            2022                    1.0
# 51           66.0            2011                    1.0
# 56           45.0            2016                    1.0
# 62           20.0            2017                    2.0
# 63           59.0            2025                    1.0
# 64           98.0            2016                    2.0
# 66           72.0            2015                    2.0
# 68           51.0            2018                    2.0
# 70           25.0            2017                    1.0
# 72           52.0            2022                    1.0
# 73           25.0            2024                    2.0
# 74           56.0            2023                    2.0
# 77            0.0            2016                    1.0
# 78           81.0            2023                    2.0
# 82           39.0            2020                    1.0
# 83           37.0            2017                    2.0
# 86           55.0            2016                    1.0
# 87           96.0            2021                    1.0

# %%
df_stud=df
ninetieth_percentile = np.percentile(df_stud['math score'], 90)
b = np.where(df_stud['math score']>ninetieth_percentile,
ninetieth_percentile, df_stud['math score'])
print("New array:",b)
# Out:
# New array: [11.  86.   1.  93.2 88.   0.  93.2 15.   3.  18.   1.  93.2 93.  10.
#  86.  92.   0.  83.  92.   8.  11.   1.   8.   5.  90.   1.  89.  86.
#  89.  11.   6.  89.  91.  11.  91.   6.  93.2 13.  10. ]

# %%
df_stud.insert(1,"m score",b,True)
df_stud
# Out:
#     Id  m score  math score  gender    Phone no  Placement Score  \
# 1    2     11.0        11.0       1  7458612988               95
# 3    4     86.0        86.0       1  7458612990               71
# 4    5      1.0         1.0       1  7458612991               25
# 10  11     93.2        94.0       0  7458612997               89
# 11  12     88.0        88.0       1  7458612998               16
# 12  13      0.0         0.0       0  7458612999               16
# 14  15     93.2       100.0       1  7458613001               28
# 15  16     15.0        15.0       1  7458613002                4
# 17  18      3.0         3.0       1  7458613004               87
# 19  20     18.0        18.0       0  7458613006               45
# 21  22      1.0         1.0       0  7458613008               15
# 24  25     93.2        95.0       1  7458613011               46
# 27  28     93.0        93.0       1  7458613014                1
# 28  29     10.0        10.0       0  7458613015               44
# 31  32     86.0        86.0       1  7458613018                9
# 33  34     92.0        92.0       0  7458613020               23
# 35  36      0.0         0.0       0  7458613022               60
# 36  37     83.0        83.0       0  7458613023               50
# 38  39     92.0        92.0       0  7458613025               17
# 44  45      8.0         8.0       0  7458613031               79
# 46  47     11.0        11.0       0  7458613033               36
# 49  50      1.0         1.0       0  7458613036                9
# 51  52      8.0         8.0       1  7458613038               31
# 56  57      5.0         5.0       1  7458613043               32
# 62  63     90.0        90.0       0  7458613049                1
# 63  64      1.0         1.0       1  7458613050               13
# 64  65     89.0        89.0       1  7458613051               19
# 66  67     86.0        86.0       0  7458613053                6
# 68  69     89.0        89.0       1  7458613055                0
# 70  71     11.0        11.0       0  7458613057               24
# 72  73      6.0         6.0       1  7458613059               66
# 73  74     89.0        89.0       0  7458613060               29
# 74  75     91.0        91.0       0  7458613061               82
# 77  78     11.0        11.0       1  7458613064               27
# 78  79     91.0        91.0       1  7458613065               27
# 82  83      6.0         6.0       0  7458613069               82
# 83  84     93.2       100.0       0  7458613070               87
# 86  87     13.0        13.0       1  7458613073               97
# 87  88     10.0        10.0       0  7458613074               25
#
#     reading score  writing score  club join year  placement offer count
# 1        46.00000           59.0            2011                    1.0
# 3        97.00000           94.0            2011                    2.0
# 4        62.00000           11.0            2015                    1.0
# 10       60.00000            4.0            2022                    2.0
# 11       73.00000           88.0            2016                    2.0
# 12        9.00000           80.0            2019                    1.0
# 14       58.00000           29.0            2019                    2.0
# 15       51.00000           50.0            2014                    1.0
# 17       76.00000           50.0            2025                    1.0
# 19       89.00000           26.0            2011                    1.0
# 21       39.00000           92.0            2024                    1.0
# 24       87.00000           86.0            2023                    2.0
# 27       36.00000           31.0            2017                    2.0
# 28       61.00000            5.0            2012                    1.0
# 31       94.00000           66.0            2024                    2.0
# 33       37.00000            2.0            2015                    2.0
# 35       25.00000           94.0            2023                    1.0
# 36       74.00000           93.0            2021                    3.0
# 38       15.00000           18.0            2013                    2.0
# 44       21.00000           45.0            2016                    1.0
# 46        5.00000            7.0            2024                    1.0
# 49       96.00000           42.0            2022                    1.0
# 51       49.00000           66.0            2011                    1.0
# 56       33.00000           45.0            2016                    1.0
# 62       41.00000           20.0            2017                    2.0
# 63       98.00000           59.0            2025                    1.0
# 64       47.00000           98.0            2016                    2.0
# 66       77.00000           72.0            2015                    2.0
# 68       62.00000           51.0            2018                    2.0
# 70      100.00000           25.0            2017                    1.0
# 72       36.00000           52.0            2022                    1.0
# 73       82.00000           25.0            2024                    2.0
# 74       99.00000           56.0            2023                    2.0
# 77       52.00000            0.0            2016                    1.0
# 78        5.00000           81.0            2023                    2.0
# 82       12.00000           39.0            2020                    1.0
# 83       55.62069           37.0            2017                    2.0
# 86       80.00000           55.0            2016                    1.0
# 87       44.00000           96.0            2021                    1.0

# %%
col = ['reading score']
df.boxplot(col)
# Out:
# <Axes: >

# %%
refined_df=df
refined_df['reading score'] = np.where(refined_df['reading score']>upr_bound, upr_bound, refined_df['reading score'])

# %%
refined_df
# Out:
#     Id  m score  math score  gender    Phone no  Placement Score  \
# 1    2     11.0        11.0       1  7458612988               95
# 3    4     86.0        86.0       1  7458612990               71
# 4    5      1.0         1.0       1  7458612991               25
# 10  11     93.2        94.0       0  7458612997               89
# 11  12     88.0        88.0       1  7458612998               16
# 12  13      0.0         0.0       0  7458612999               16
# 14  15     93.2       100.0       1  7458613001               28
# 15  16     15.0        15.0       1  7458613002                4
# 17  18      3.0         3.0       1  7458613004               87
# 19  20     18.0        18.0       0  7458613006               45
# 21  22      1.0         1.0       0  7458613008               15
# 24  25     93.2        95.0       1  7458613011               46
# 27  28     93.0        93.0       1  7458613014                1
# 28  29     10.0        10.0       0  7458613015               44
# 31  32     86.0        86.0       1  7458613018                9
# 33  34     92.0        92.0       0  7458613020               23
# 35  36      0.0         0.0       0  7458613022               60
# 36  37     83.0        83.0       0  7458613023               50
# 38  39     92.0        92.0       0  7458613025               17
# 44  45      8.0         8.0       0  7458613031               79
# 46  47     11.0        11.0       0  7458613033               36
# 49  50      1.0         1.0       0  7458613036                9
# 51  52      8.0         8.0       1  7458613038               31
# 56  57      5.0         5.0       1  7458613043               32
# 62  63     90.0        90.0       0  7458613049                1
# 63  64      1.0         1.0       1  7458613050               13
# 64  65     89.0        89.0       1  7458613051               19
# 66  67     86.0        86.0       0  7458613053                6
# 68  69     89.0        89.0       1  7458613055                0
# 70  71     11.0        11.0       0  7458613057               24
# 72  73      6.0         6.0       1  7458613059               66
# 73  74     89.0        89.0       0  7458613060               29
# 74  75     91.0        91.0       0  7458613061               82
# 77  78     11.0        11.0       1  7458613064               27
# 78  79     91.0        91.0       1  7458613065               27
# 82  83      6.0         6.0       0  7458613069               82
# 83  84     93.2       100.0       0  7458613070               87
# 86  87     13.0        13.0       1  7458613073               97
# 87  88     10.0        10.0       0  7458613074               25
#
#     reading score  writing score  club join year  placement offer count
# 1        46.00000           59.0            2011                    1.0
# 3        97.00000           94.0            2011                    2.0
# 4        62.00000           11.0            2015                    1.0
# 10       60.00000            4.0            2022                    2.0
# 11       73.00000           88.0            2016                    2.0
# 12        9.00000           80.0            2019                    1.0
# 14       58.00000           29.0            2019                    2.0
# 15       51.00000           50.0            2014                    1.0
# 17       76.00000           50.0            2025                    1.0
# 19       89.00000           26.0            2011                    1.0
# 21       39.00000           92.0            2024                    1.0
# 24       87.00000           86.0            2023                    2.0
# 27       36.00000           31.0            2017                    2.0
# 28       61.00000            5.0            2012                    1.0
# 31       94.00000           66.0            2024                    2.0
# 33       37.00000            2.0            2015                    2.0
# 35       25.00000           94.0            2023                    1.0
# 36       74.00000           93.0            2021                    3.0
# 38       15.00000           18.0            2013                    2.0
# 44       21.00000           45.0            2016                    1.0
# 46        5.00000            7.0            2024                    1.0
# 49       96.00000           42.0            2022                    1.0
# 51       49.00000           66.0            2011                    1.0
# 56       33.00000           45.0            2016                    1.0
# 62       41.00000           20.0            2017                    2.0
# 63       98.00000           59.0            2025                    1.0
# 64       47.00000           98.0            2016                    2.0
# 66       77.00000           72.0            2015                    2.0
# 68       62.00000           51.0            2018                    2.0
# 70      100.00000           25.0            2017                    1.0
# 72       36.00000           52.0            2022                    1.0
# 73       82.00000           25.0            2024                    2.0
# 74       99.00000           56.0            2023                    2.0
# 77       52.00000            0.0            2016                    1.0
# 78        5.00000           81.0            2023                    2.0
# 82       12.00000           39.0            2020                    1.0
# 83       55.62069           37.0            2017                    2.0
# 86       80.00000           55.0            2016                    1.0
# 87       44.00000           96.0            2021                    1.0

# %%
col = ['reading score']
refined_df.boxplot(col)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
new_df['math score'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['log_math'] = np.log10(df['math score'])

# %%
df['log_math']
# Out:
# 1     1.041393
# 3     1.934498
# 4     0.000000
# 10    1.973128
# 11    1.944483
# 12        -inf
# 14    2.000000
# 15    1.176091
# 17    0.477121
# 19    1.255273
# 21    0.000000
# 24    1.977724
# 27    1.968483
# 28    1.000000
# 31    1.934498
# 33    1.963788
# 35        -inf
# 36    1.919078
# 38    1.963788
# 44    0.903090
# 46    1.041393
# 49    0.000000
# 51    0.903090
# 56    0.698970
# 62    1.954243
# 63    0.000000
# 64    1.949390
# 66    1.934498
# 68    1.949390
# 70    1.041393
# 72    0.778151
# 73    1.949390
# 74    1.959041
# 77    1.041393
# 78    1.959041
# 82    0.778151
# 83    2.000000
# 86    1.113943
# 87    1.000000
# Name: log_math, dtype: float64

# %%
import numpy as np

df.loc[np.isfinite(df['log_math']), 'log_math'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>
